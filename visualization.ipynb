# %%
import numpy as np

data = np.load('DTM_s3_v1.npy')

print((type(data)))
print(data.shape)
print(data)
# Out:
# <class 'numpy.ndarray'>
# (5642, 20)
# [[ 0.25024124  0.66059172 -0.16565239 ... -0.52941911  0.34231188
#    0.54734674]
#  [-0.64897176  0.50791708  0.06062978 ... -0.60732899 -0.89579157
#   -0.22056557]
#  [-0.47517926 -0.12728137  0.45113116 ...  0.07425034 -0.92200143
#    0.22949202]
#  ...
#  [ 1.01101106 -0.327226   -1.71705157 ...  1.25966809 -0.41065249
#   -0.10218789]
#  [ 1.28529874  0.39606121 -1.35008207 ... -0.20692194 -0.74729215
#    0.36525653]
#  [-0.74732025 -2.31458448 -2.55654108 ...  0.30225101  1.23256714
#    0.85163719]]

# %%
import pandas as pd

column_names = [f'Topic_{i+1}' for i in range(data.shape[1])]
df = pd.DataFrame(data, columns=column_names)

# %%
df.head()
# Out:
#     Topic_1   Topic_2   Topic_3   Topic_4   Topic_5   Topic_6   Topic_7  \
# 0  0.250241  0.660592 -0.165652 -0.835686 -1.944637  0.985141 -1.018437
# 1 -0.648972  0.507917  0.060630 -0.842115 -0.536268  0.978298 -1.336591
# 2 -0.475179 -0.127281  0.451131 -0.770698 -0.288490  0.259277 -0.351288
# 3  0.076954  0.792768  0.241053 -0.546085 -0.774069  0.407038 -0.314924
# 4  0.551156 -0.552124  0.314609 -0.980737  0.821192  1.073193 -1.375534
#
#     Topic_8   Topic_9  Topic_10  Topic_11  Topic_12  Topic_13  Topic_14  \
# 0  0.744026 -0.364578  0.908786 -0.197280  1.841018  0.751607 -1.110062
# 1 -0.011209 -0.017963  0.311446 -0.707183  1.249116  0.866541 -0.852237
# 2 -0.218104 -0.381744  0.261291  0.034069  1.279759  1.046483  0.066575
# 3  0.118452 -0.824417  0.453472 -1.345340  0.831641  0.786537 -0.837327
# 4  0.923714  0.391577 -0.373275 -0.681295 -0.353499 -0.018216 -0.353042
#
#    Topic_15  Topic_16  Topic_17  Topic_18  Topic_19  Topic_20
# 0  2.180673 -0.400127 -2.059017 -0.529419  0.342312  0.547347
# 1  2.384833 -1.076000 -2.513708 -0.607329 -0.895792 -0.220566
# 2  3.359023 -0.027234 -1.163790  0.074250 -0.922001  0.229492
# 3  3.566029  0.612187 -0.662962  0.208791  0.182432  0.314418
# 4 -0.854733 -0.239138 -2.251914  1.301816  0.184084 -0.184006

# %%
from turftopic import load_model

model = load_model('janko/s3_scriptum')
model.print_topics()
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Highest Ranking                                   ┃ Lowest Ranking                                   ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ učitelské, pedagogové, učitelský, loktem,         │ masaryk, masarykovy, masaryka, masarykem,        │
# │          │ učitelku                                          │ masarykových                                     │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        1 │ vincenzo, návštěvníka, autobusem, hlubokému,      │ jai, jaou, jeou, aoy, jato                       │
# │          │ vernisáži                                         │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        2 │ slovaques, slovaks, slovakia, hess, slovak        │ 199, 1985, 1989, 1983, připomeňme                │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        3 │ listu, listy, listů, poštovného, posta            │ sks, srpnu, socialis, slezsku, slunné            │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        4 │ cirkevných, biskupských, církevních, katolických, │ příroda, zatmění, šumění, nature, dušiček        │
# │          │ církevními                                        │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        5 │ režimu, lenin, jelínka, jelínek, leninismus       │ austrália, australian, australské, austrálie,    │
# │          │                                                   │ australia                                        │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        6 │ výkřiky, nevydrželi, odzbrojeni, nedočkali,       │ vědu, věda, vědou, sciences, sci                 │
# │          │ výkřikem                                          │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        7 │ zdmi, srpem, padaly, padl, kalandra               │ husákovým, husit, bisk, husák, boská             │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        8 │ congressional, tennessee, senate, carolina,       │ český, balkán, sovětech, českí, českého          │
# │          │ congress                                          │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │        9 │ žaloba, obžalován, obžalovanému, obžalovaných,    │ 1935, západ, pokolením, 1936, západoněmečtí      │
# │          │ obviněn                                           │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       10 │ sopka, oklahoma, dining, steak, gromyka           │ hitlerv, xvi, xvii, egyptských, xviii            │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       11 │ citizens, conscience, spoluobčany, spoluobčanm,   │ 1298, znamenité, římští, staročeské, 1297        │
# │          │ responsibility                                    │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       12 │ hospodářství, hospodárstva, hospodárstvo,         │ útěchu, útěcha, útěchou, tajemníci, dopisoval    │
# │          │ hospodárskych, hospodárske                        │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       13 │ československo, čechoslováci, československa,     │ concert, koncertní, hudební, koncertních,        │
# │          │ československu, českosloven                       │ koncerty                                         │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       14 │ bible, bohoslužba, božstvo, božského, božské      │ západoněmec, západoněmecký, západoněmeckou,      │
# │          │                                                   │ nacistické, jezdila                              │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       15 │ dubčekovy, husákovi, dubčekovi, dubčeka,          │ frankfurt, zürich, frankfurtě, frankfurtu,       │
# │          │ dubčekovo                                         │ frankfurter                                      │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       16 │ českosloven, velen, vyšehrad, kyjev, vln          │ autorit, accountant, publishing, pochybuje,      │
# │          │                                                   │ paradoxy                                         │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       17 │ čtenářských, čtenářský, čtenářskou, čtenářm,      │ goebbels, gestapu, soviets, špionáž, sovieti     │
# │          │ čtenářská                                         │                                                  │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       18 │ skautských, skautském, skauti, skautské,          │ kapitalist, mojžíš, materialismus, kapitalisty,  │
# │          │ skautingu                                         │ marxist                                          │
# ├──────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────┤
# │       19 │ rumun, umenia, danube, vaňka, rumuny              │ sokolství, tělovýchovy, sokolští, sokolské,      │
# │          │                                                   │ sokolským                                        │
# └──────────┴───────────────────────────────────────────────────┴──────────────────────────────────────────────────┘

# %%
from turftopic import load_model
import topicwizard
import pandas as pd

df_topics = pd.read_csv('keywordProbs.csv')


topicwizard.visualize(df_topics['Highest Ranking'].tolist(), model)
# Out:
# Preprocessing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       3 import pandas as pd
#       5 df_topics = pd.read_csv('keywordProbs.csv')
# ----> 8 topicwizard.visualize(df_topics['Highest Ranking'].tolist(), model)
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/topicwizard/app.py:268, in visualize(corpus, model, topic_data, document_names, exclude_pages, group_labels, port, wordcloud_font_path, **kwargs)
#     264     if (model is None) or (corpus is None):
#     265         raise TypeError(
#     266             "Either corpus and model or topic_data has to be specified."
#     267         )
# --> 268     topic_data = model.prepare_topic_data(corpus, **kwargs)
#     269 exclude_pages = set() if exclude_pages is None else set(exclude_pages)
#     270 # We filter out all documents that contain nans
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/turftopic/base.py:134, in ContextualModel.prepare_topic_data(self, corpus, embeddings)
#     118 """Produces topic inference data for a given corpus, that can be then used and reused.
#     119 Exists to allow visualizations out of the box with topicwizard.
#     120
#    (...)    131     Information about topical inference in a dictionary.
#     132 """
#     133 if embeddings is None:
# --> 134     embeddings = self.encode_documents(corpus)
#     135 try:
#     136     document_topic_matrix = self.transform(
#     137         corpus, embeddings=embeddings
#     138     )
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/turftopic/base.py:44, in ContextualModel.encode_documents(self, raw_documents)
#      42 if not hasattr(self.encoder_, "encode"):
#      43     return self.encoder.get_text_embeddings(list(raw_documents))
# ---> 44 return self.encoder_.encode(raw_documents)
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:653, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     651 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#     652     sentences_batch = sentences_sorted[start_index : start_index + batch_size]
# --> 653     features = self.tokenize(sentences_batch)
#     654     if self.device.type == "hpu":
#     655         if "input_ids" in features:
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:1124, in SentenceTransformer.tokenize(self, texts)
#    1113 def tokenize(self, texts: list[str] | list[dict] | list[tuple[str, str]]) -> dict[str, Tensor]:
#    1114     """
#    1115     Tokenizes the texts.
#    1116
#    (...)   1122             "attention_mask", and "token_type_ids".
#    1123     """
# -> 1124     return self._first_module().tokenize(texts)
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:500, in Transformer.tokenize(self, texts, padding)
#     496 if self.do_lower_case:
#     497     to_tokenize = [[s.lower() for s in col] for col in to_tokenize]
#     499 output.update(
# --> 500     self.tokenizer(
#     501         *to_tokenize,
#     502         padding=padding,
#     503         truncation="longest_first",
#     504         return_tensors="pt",
#     505         max_length=self.max_seq_length,
#     506     )
#     507 )
#     508 return output
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2867, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2865     if not self._in_target_context_manager:
#    2866         self._switch_to_input_mode()
# -> 2867     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2868 if text_target is not None:
#    2869     self._switch_to_target_mode()
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2955, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2950         raise ValueError(
#    2951             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2952             f" {len(text_pair)}."
#    2953         )
#    2954     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2955     return self.batch_encode_plus(
#    2956         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2957         add_special_tokens=add_special_tokens,
#    2958         padding=padding,
#    2959         truncation=truncation,
#    2960         max_length=max_length,
#    2961         stride=stride,
#    2962         is_split_into_words=is_split_into_words,
#    2963         pad_to_multiple_of=pad_to_multiple_of,
#    2964         padding_side=padding_side,
#    2965         return_tensors=return_tensors,
#    2966         return_token_type_ids=return_token_type_ids,
#    2967         return_attention_mask=return_attention_mask,
#    2968         return_overflowing_tokens=return_overflowing_tokens,
#    2969         return_special_tokens_mask=return_special_tokens_mask,
#    2970         return_offsets_mapping=return_offsets_mapping,
#    2971         return_length=return_length,
#    2972         verbose=verbose,
#    2973         split_special_tokens=split_special_tokens,
#    2974         **kwargs,
#    2975     )
#    2976 else:
#    2977     return self.encode_plus(
#    2978         text=text,
#    2979         text_pair=text_pair,
#    (...)   2997         **kwargs,
#    2998     )
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:3147, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3130 """
#    3131 Tokenize and prepare for the model a list of sequences or a list of pairs of sequences.
#    3132
#    (...)   3143         details in `encode_plus`).
#    3144 """
#    3146 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
# -> 3147 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3148     padding=padding,
#    3149     truncation=truncation,
#    3150     max_length=max_length,
#    3151     pad_to_multiple_of=pad_to_multiple_of,
#    3152     verbose=verbose,
#    3153     **kwargs,
#    3154 )
#    3156 return self._batch_encode_plus(
#    3157     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3158     add_special_tokens=add_special_tokens,
#    (...)   3175     **kwargs,
#    3176 )
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2768, in PreTrainedTokenizerBase._get_padding_truncation_strategies(self, padding, truncation, max_length, pad_to_multiple_of, verbose, **kwargs)
#    2765             max_length = self.model_max_length
#    2767 # Test if we have a padding token
# -> 2768 if padding_strategy != PaddingStrategy.DO_NOT_PAD and (self.pad_token is None or self.pad_token_id < 0):
#    2769     raise ValueError(
#    2770         "Asking to pad but the tokenizer does not have a padding token. "
#    2771         "Please select a token to use as `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` "
#    2772         "or add a new pad token via `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`."
#    2773     )
#    2775 # Check that we will truncate to a multiple of pad_to_multiple_of if both are provided
#
# File ~/SCRIPTUM/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1111, in SpecialTokensMixin.__getattr__(self, key)
#    1108         return self.convert_tokens_to_ids(attr_as_tokens) if attr_as_tokens is not None else None
#    1110 if key not in self.__dict__:
# -> 1111     raise AttributeError(f"{self.__class__.__name__} has no attribute {key}")
#    1112 else:
#    1113     return super().__getattr__(key)
#
# AttributeError: XLMRobertaTokenizerFast has no attribute pad_token

# %%
from datasets import load_dataset

scriptum_dataset = load_dataset('janko/scriptum')
scriptum_df = scriptum_dataset['train'].to_pandas()
scriptum_df.head()
# Out:
#   periodical_category                             periodical_href  \
# 0            samizdat                        /cs/periodika/ps-psi
# 1            samizdat                        /cs/periodika/ps-psi
# 2            samizdat                        /cs/periodika/ps-psi
# 3            samizdat                        /cs/periodika/ps-psi
# 4            samizdat  /cs/periodika/acta-incognitorum-eruditorum
#
#                periodical_title  \
# 0                       Ψ [Psí]
# 1                       Ψ [Psí]
# 2                       Ψ [Psí]
# 3                       Ψ [Psí]
# 4  Acta incognitorum eruditorum
#
#                                periodical_basic_info  \
# 0  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 1  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 2  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 3  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 4  ['', ' [Praha] ', ' 1976 – 1988 ', ' měsíčně v...
#
#                                             file_url  \
# 0  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 1  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 2  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 3  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 4  https://files.scriptum.cz/scriptum/acta-incogn...
#
#                                                 file    year  pages_N  \
# 0                            psi_1986_2_vina_ocr.txt  1986.0       36
# 1           psi_1987_3_freud-a-psychoanalyza_ocr.txt  1987.0       42
# 2  psi_1988_4_sluzba-zivotu_rok-blahoslavene-anez...  1988.0       25
# 3           psi_1989_5_vira-v-modernim-svete_ocr.txt  1989.0       36
# 4           acta-incognitorum_1976_r01_01-02_ocr.txt  1976.0      225
#
#    tokens_N  Unnamed: 0                                               text  \
# 0     24524           0  V V I N N V V I N N N A V V I N N N A A V V I ...
# 1     21575           0  [ 3 ] 0000000 0 ooooon 0 uo 0000000 0 0 0 o 0 ...
# 2     14764           0  oooo o 0 0 0 o o o O O O 00000 o 1988 o [pagee...
# 3     23867           0  c>c 0 0 k.01 0 0 c1 0 u c1 Ü 0 0'Q 1 0 C1° 0 0...
# 4     60128           0  [pageend1]1 — ročník I. květen 1976 ACTA INCOG...
#
#                                         cleaned_text  ANNOTATION
# 0  V V I N N V V I N N N A V V I N N N A A V V I ...         NaN
# 1  [ 3 ] 0000000 0 ooooon 0 uo 0000000 0 0 0 o 0 ...         NaN
# 2  oooo o 0 0 0 o o o O O O 00000 o 1988 o uo° .....         NaN
# 3  cc 0 0 k.01 0 0 c1 0 u c1 Ü 0 0'Q 1 0 C1° 0 0l...         NaN
# 4  1 — ročník I. květen 1976 ACTA INCOGNITORUM 1 ...         NaN

# %%
merged_df = pd.merge(scriptum_df, df, left_index=True, right_index=True, how='inner')

merged_df.head()
# Out:
#   periodical_category                             periodical_href  \
# 0            samizdat                        /cs/periodika/ps-psi
# 1            samizdat                        /cs/periodika/ps-psi
# 2            samizdat                        /cs/periodika/ps-psi
# 3            samizdat                        /cs/periodika/ps-psi
# 4            samizdat  /cs/periodika/acta-incognitorum-eruditorum
#
#                periodical_title  \
# 0                       Ψ [Psí]
# 1                       Ψ [Psí]
# 2                       Ψ [Psí]
# 3                       Ψ [Psí]
# 4  Acta incognitorum eruditorum
#
#                                periodical_basic_info  \
# 0  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 1  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 2  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 3  ['', ' [Praha] ', ' 1985 – 1989 ', ' 1 × ročně...
# 4  ['', ' [Praha] ', ' 1976 – 1988 ', ' měsíčně v...
#
#                                             file_url  \
# 0  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 1  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 2  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 3  https://files.scriptum.cz/scriptum/%5Bnode%5D/...
# 4  https://files.scriptum.cz/scriptum/acta-incogn...
#
#                                                 file    year  pages_N  \
# 0                            psi_1986_2_vina_ocr.txt  1986.0       36
# 1           psi_1987_3_freud-a-psychoanalyza_ocr.txt  1987.0       42
# 2  psi_1988_4_sluzba-zivotu_rok-blahoslavene-anez...  1988.0       25
# 3           psi_1989_5_vira-v-modernim-svete_ocr.txt  1989.0       36
# 4           acta-incognitorum_1976_r01_01-02_ocr.txt  1976.0      225
#
#    tokens_N  Unnamed: 0  ...  Topic_11  Topic_12  Topic_13  Topic_14  \
# 0     24524           0  ... -0.197280  1.841018  0.751607 -1.110062
# 1     21575           0  ... -0.707183  1.249116  0.866541 -0.852237
# 2     14764           0  ...  0.034069  1.279759  1.046483  0.066575
# 3     23867           0  ... -1.345340  0.831641  0.786537 -0.837327
# 4     60128           0  ... -0.681295 -0.353499 -0.018216 -0.353042
#
#    Topic_15  Topic_16  Topic_17  Topic_18  Topic_19  Topic_20
# 0  2.180673 -0.400127 -2.059017 -0.529419  0.342312  0.547347
# 1  2.384833 -1.076000 -2.513708 -0.607329 -0.895792 -0.220566
# 2  3.359023 -0.027234 -1.163790  0.074250 -0.922001  0.229492
# 3  3.566029  0.612187 -0.662962  0.208791  0.182432  0.314418
# 4 -0.854733 -0.239138 -2.251914  1.301816  0.184084 -0.184006
#
# [5 rows x 33 columns]
